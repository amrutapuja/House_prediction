# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('kc_house_data.csv')

# %%
data
# Out:
#                id             date        price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000 221900.00000         3    1.00000
# 1      6414100192  20141209T000000 538000.00000         3    2.25000
# 2      5631500400  20150225T000000 180000.00000         2    1.00000
# 3      2487200875  20141209T000000 604000.00000         4    3.00000
# 4      1954400510  20150218T000000 510000.00000         3    2.00000
# ...           ...              ...          ...       ...        ...
# 21608   263000018  20140521T000000 360000.00000         3    2.50000
# 21609  6600060120  20150223T000000 400000.00000         4    2.50000
# 21610  1523300141  20140623T000000 402101.00000         2    0.75000
# 21611   291310100  20150116T000000 400000.00000         3    2.50000
# 21612  1523300157  20141015T000000 325000.00000         2    0.75000
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650 1.00000           0     0  ...      7
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
data.shape
# Out:
# (21613, 21)

# %%
pd.set_option('display.float_format',lambda x: '%.5f'%x)

# %%
data.describe()
# Out:
#                     id         price    bedrooms   bathrooms  sqft_living  \
# count      21613.00000   21613.00000 21613.00000 21613.00000  21613.00000
# mean  4580301520.86499  540088.14177     3.37084     2.11476   2079.89974
# std   2876565571.31205  367127.19648     0.93006     0.77016    918.44090
# min      1000102.00000   75000.00000     0.00000     0.00000    290.00000
# 25%   2123049194.00000  321950.00000     3.00000     1.75000   1427.00000
# 50%   3904930410.00000  450000.00000     3.00000     2.25000   1910.00000
# 75%   7308900445.00000  645000.00000     4.00000     2.50000   2550.00000
# max   9900000190.00000 7700000.00000    33.00000     8.00000  13540.00000
#
#            sqft_lot      floors  waterfront        view   condition  \
# count   21613.00000 21613.00000 21613.00000 21613.00000 21613.00000
# mean    15106.96757     1.49431     0.00754     0.23430     3.40943
# std     41420.51152     0.53999     0.08652     0.76632     0.65074
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
sns.boxplot(x='bedrooms',y='price',data=data)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# # spliting the data for train and testing

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
x=data[[ 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']]

# %%
x
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3    1.00000         1180      5650 1.00000           0     0
# 1             3    2.25000         2570      7242 2.00000           0     0
# 2             2    1.00000          770     10000 1.00000           0     0
# 3             4    3.00000         1960      5000 1.00000           0     0
# 4             3    2.00000         1680      8080 1.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3    2.50000         1530      1131 3.00000           0     0
# 21609         4    2.50000         2310      5813 2.00000           0     0
# 21610         2    0.75000         1020      1350 2.00000           0     0
# 21611         3    2.50000         1600      2388 2.00000           0     0
# 21612         2    0.75000         1020      1076 2.00000           0     0
#
# ...

# %%
y=data['price']

# %%
y
# Out:
# 0       221900.00000
# 1       538000.00000
# 2       180000.00000
# 3       604000.00000
# 4       510000.00000
#             ...
# 21608   360000.00000
# 21609   400000.00000
# 21610   402101.00000
# 21611   400000.00000
# 21612   325000.00000
# Name: price, Length: 21613, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=101)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19642         4    2.50000         2070      4270 2.00000           0     0
# 8626          3    2.25000         1400      6970 2.00000           0     0
# 6954          5    3.00000         2190      4900 2.00000           0     0
# 20242         4    2.50000         2547      4800 2.00000           0     0
# 10376         5    3.50000         4060      8309 2.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3    2.25000         1920      9672 2.00000           0     0
# 8006          3    1.00000         1240      3600 1.50000           0     0
# 17745         3    2.25000         1780      7332 2.00000           0     0
# 17931         2    1.00000         1150      5000 1.00000           0     0
# 13151         3    1.00000         1450      7930 1.00000           0     0
#
# ...

# %%
x_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 19642         4    2.50000         2070      4270 2.00000           0     0
# 8626          3    2.25000         1400      6970 2.00000           0     0
# 6954          5    3.00000         2190      4900 2.00000           0     0
# 20242         4    2.50000         2547      4800 2.00000           0     0
# 10376         5    3.50000         4060      8309 2.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 5695          3    2.25000         1920      9672 2.00000           0     0
# 8006          3    1.00000         1240      3600 1.50000           0     0
# 17745         3    2.25000         1780      7332 2.00000           0     0
# 17931         2    1.00000         1150      5000 1.00000           0     0
# 13151         3    1.00000         1450      7930 1.00000           0     0
#
# ...

# %%
y_train
# Out:
# 19642   493000.00000
# 8626    425000.00000
# 6954    588000.00000
# 20242   392440.00000
# 10376   630000.00000
#             ...
# 5695    625000.00000
# 8006    390000.00000
# 17745   272450.00000
# 17931   552000.00000
# 13151   394000.00000
# Name: price, Length: 16209, dtype: float64

# %%
x_test
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3834          2    1.00000         1050      6317 1.50000           0     0
# 1348          4    2.25000         2040      9565 1.00000           0     0
# 20366         4    2.50000         2500      4000 2.00000           0     0
# 16617         5    2.00000         2360     19899 1.00000           0     0
# 20925         3    3.00000         1670      4440 1.00000           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 7148          3    1.75000         1520      5500 1.50000           0     0
# 2747          5    3.00000         2970     10335 2.00000           0     0
# 15565         3    2.50000         3440    103672 2.00000           0     0
# 21238         3    2.50000         1572      4000 2.00000           0     0
# 2333          3    3.00000         2920     23085 1.50000           0     2
#
# ...

# %%
y_test
# Out:
# 3834    349950.00000
# 1348    450000.00000
# 20366   635000.00000
# 16617   355500.00000
# 20925   246950.00000
#             ...
# 7148    738000.00000
# 2747    726000.00000
# 15565   560000.00000
# 21238   299000.00000
# 2333    555000.00000
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
x_test_std=std.fit_transform(x_test)

# %%
x_test_std
# Out:
# array([[-1.3754624 , -1.43326156, -1.09911515, ...,  1.67980996,
#         -0.55627946, -0.12758442],
#        [ 0.62561414,  0.18115929, -0.05030429, ..., -0.85640282,
#         -0.1414542 , -0.16627888],
#        [ 0.62561414,  0.50404346,  0.43702198, ..., -0.68445619,
#         -0.72793129, -0.32613632],
#        ...,
#        [-0.37492413,  0.50404346,  1.4328626 , ...,  1.64398775,
#          1.03149996,  3.72707141],
#        [-0.37492413,  0.50404346, -0.54610579, ...,  0.12512586,
#         -0.544836  , -0.29345519],
#        [-0.37492413,  1.1498118 ,  0.88197204, ..., -1.2862694 ,
#          0.40210992,  0.19227985]])

# %%
x_train_std=std.fit_transform(x_train)

# %%
x_train_std
# Out:
# array([[ 0.69608634,  0.49894508, -0.00810266, ..., -0.36553755,
#          0.12372791, -0.29371924],
#        [-0.40802008,  0.173745  , -0.74457445, ...,  0.20797682,
#         -0.27289927, -0.16524962],
#        [ 1.80019275,  1.14934525,  0.12380274, ..., -1.2222689 ,
#         -0.90456477, -0.29386481],
#        ...,
#        [-0.40802008,  0.173745  , -0.32687403, ...,  1.14967325,
#         -0.69890623, -0.18399236],
#        [-1.51212649, -1.45225542, -1.01937736, ..., -0.73371962,
#         -0.76794874, -0.3042734 ],
#        [-0.40802008, -1.45225542, -0.68961387, ..., -1.11606253,
#         -1.38933131, -0.17980708]])

# %%
y_train
# Out:
# 19642   493000.00000
# 8626    425000.00000
# 6954    588000.00000
# 20242   392440.00000
# 10376   630000.00000
#             ...
# 5695    625000.00000
# 8006    390000.00000
# 17745   272450.00000
# 17931   552000.00000
# 13151   394000.00000
# Name: price, Length: 16209, dtype: float64

# %%
y_test
# Out:
# 3834    349950.00000
# 1348    450000.00000
# 20366   635000.00000
# 16617   355500.00000
# 20925   246950.00000
#             ...
# 7148    738000.00000
# 2747    726000.00000
# 15565   560000.00000
# 21238   299000.00000
# 2333    555000.00000
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# # Model training

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
x_train_std=std.fit_transform(x_train)

# %%
x_train_std
# Out:
# array([[ 0.69608634,  0.49894508, -0.00810266, ..., -0.36553755,
#          0.12372791, -0.29371924],
#        [-0.40802008,  0.173745  , -0.74457445, ...,  0.20797682,
#         -0.27289927, -0.16524962],
#        [ 1.80019275,  1.14934525,  0.12380274, ..., -1.2222689 ,
#         -0.90456477, -0.29386481],
#        ...,
#        [-0.40802008,  0.173745  , -0.32687403, ...,  1.14967325,
#         -0.69890623, -0.18399236],
#        [-1.51212649, -1.45225542, -1.01937736, ..., -0.73371962,
#         -0.76794874, -0.3042734 ],
#        [-0.40802008, -1.45225542, -0.68961387, ..., -1.11606253,
#         -1.38933131, -0.17980708]])

# %%
x_test_std=std.transform(x_test)

# %%
x_test_std
# Out:
# array([[-1.51212649, -1.45225542, -1.12929852, ...,  1.64530296,
#         -0.56669717, -0.11153258],
#        [ 0.69608634,  0.173745  , -0.04107901, ..., -0.86116726,
#         -0.14069021, -0.14923641],
#        [ 0.69608634,  0.49894508,  0.46455834, ..., -0.69123707,
#         -0.74297592, -0.30500127],
#        ...,
#        [-0.40802008,  0.49894508,  1.49781727, ...,  1.60990083,
#          1.06388121,  3.64443868],
#        [-0.40802008,  0.49894508, -0.55551005, ...,  0.10885088,
#         -0.55494526, -0.27315682],
#        [-0.40802008,  1.14934525,  0.92622723, ..., -1.28599272,
#          0.41752581,  0.20014272]])

# %%
lr.fit(x_train_std,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_std)

# %%
y_test
# Out:
# 3834    349950.00000
# 1348    450000.00000
# 20366   635000.00000
# 16617   355500.00000
# 20925   246950.00000
#             ...
# 7148    738000.00000
# 2747    726000.00000
# 15565   560000.00000
# 21238   299000.00000
# 2333    555000.00000
# Name: price, Length: 5404, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 125097.38548310271

# %%
x_test.loc[7148]
# Out:
# bedrooms           3.00000
# bathrooms          1.75000
# sqft_living     1520.00000
# sqft_lot        5500.00000
# floors             1.50000
# waterfront         0.00000
# view               0.00000
# condition          5.00000
# grade              7.00000
# sqft_above      1520.00000
# sqft_basement      0.00000
# yr_built        1936.00000
# yr_renovated       0.00000
# lat               47.58390
# long            -122.38300
# sqft_living15   2310.00000
# sqft_lot15      5500.00000
# Name: 7148, dtype: float64

# %%
lr.predict([[3,1,1520,5500,1,0,0,3,8,1000,1,1980,0,40,0,2000,5000]])
# Out:
# array([82124684.70629959])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7058971988480449

# %%
import pickle
import os

# %%
scaler_path=os.path.join('C:/Users/aradhya/Desktop/Prodigy_infotech_internship/Task 1','models/scaler.pkl')
with open(scaler_path,'wb') as scaler_file:
    pickle.dump(std,scaler_file)

# %%
x_train_std
# Out:
# array([[ 0.69608634,  0.49894508, -0.00810266, ..., -0.36553755,
#          0.12372791, -0.29371924],
#        [-0.40802008,  0.173745  , -0.74457445, ...,  0.20797682,
#         -0.27289927, -0.16524962],
#        [ 1.80019275,  1.14934525,  0.12380274, ..., -1.2222689 ,
#         -0.90456477, -0.29386481],
#        ...,
#        [-0.40802008,  0.173745  , -0.32687403, ...,  1.14967325,
#         -0.69890623, -0.18399236],
#        [-1.51212649, -1.45225542, -1.01937736, ..., -0.73371962,
#         -0.76794874, -0.3042734 ],
#        [-0.40802008, -1.45225542, -0.68961387, ..., -1.11606253,
#         -1.38933131, -0.17980708]])

# %%
x_test_std
# Out:
# array([[-1.51212649, -1.45225542, -1.12929852, ...,  1.64530296,
#         -0.56669717, -0.11153258],
#        [ 0.69608634,  0.173745  , -0.04107901, ..., -0.86116726,
#         -0.14069021, -0.14923641],
#        [ 0.69608634,  0.49894508,  0.46455834, ..., -0.69123707,
#         -0.74297592, -0.30500127],
#        ...,
#        [-0.40802008,  0.49894508,  1.49781727, ...,  1.60990083,
#          1.06388121,  3.64443868],
#        [-0.40802008,  0.49894508, -0.55551005, ...,  0.10885088,
#         -0.55494526, -0.27315682],
#        [-0.40802008,  1.14934525,  0.92622723, ..., -1.28599272,
#          0.41752581,  0.20014272]])

# %%
import joblib
model_path=os.path.join('C:/Users/aradhya/Desktop/Prodigy_infotech_internship/Task 1','models/dt.sav')
joblib.dump(lr,model_path)
# Out:
# ['C:/Users/aradhya/Desktop/Prodigy_infotech_internship/Task 1\\models/dt.sav']
